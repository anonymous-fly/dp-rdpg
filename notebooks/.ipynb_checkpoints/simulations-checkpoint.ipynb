# %%
using DrWatson

# %%
include(srcdir("rdpg.jl"))
import Main.rdpg
using PersistenceDiagrams, Pipe, Plots, ProgressMeter, Random, Ripserer, Statistics, StatsBase

# %%
function generate_sbm(n, k, p, r)
    f = (x, y) -> r + p * (x == y)
    Z = rand(1:k, n)
    return rdpg.Adjacency(f, Z)
end
# Out:
# generate_sbm (generic function with 1 method)

# %%
params = (; p=0.25, r=0.5, clust=4, d=2, order=0, q=Inf, repeats=30)

N = [500, 1000, 2000]
ϵ = [1.0:0.5:5...]
n = length(ϵ);

# %%
with_eps    = [zeros(params.repeats, n) for _ in eachindex(N)];
without_eps = [zeros(params.repeats, n) for _ in eachindex(N)];

prog = ProgressMeter.Progress(convert(Int, n * params.repeats * length(N)))

Random.seed!(2022)


for j in eachindex(N)
    
    A = generate_sbm(N[j], params.clust, params.p, params.r)
    X, _, _ = rdpg.spectralEmbed(A, d=params.d, scale=false)
    X_norm = rdpg.scale_embeddings(X)
    DX = rdpg.diagram(X |> rdpg.subsample, dim_max=params.order)
    DX_norm = rdpg.diagram(X_norm |> rdpg.subsample, dim_max=params.order)

    for i in 1:n, k in 1:params.repeats
            
        A1 = rdpg.edgeFlip(A, ϵ=ϵ[i])            
        X1, _ = rdpg.spectralEmbed(A1, d=params.d, scale=false)
        X1_norm = rdpg.scale_embeddings(X1)
        D1_norm = rdpg.diagram(X1_norm |> rdpg.subsample, dim_max=params.order)
        without_eps[j][k, i] = rdpg.bottleneck_distance(DX_norm, D1_norm, order=params.order, p=params.q)

        A2 = (A1 .- rdpg.τ(ϵ[i])^2) ./ rdpg.σ(ϵ[i])^2
        X2, _ = rdpg.spectralEmbed(A2, d=params.d, scale=false)
        D2 = rdpg.diagram(X2 |> rdpg.subsample, dim_max=params.order)
        with_eps[j][k, i] = rdpg.bottleneck_distance(DX, D2, order=params.order, p=params.q)
            
        next!(prog)
    end
end
# Out:
# Progress:  55%|██████████████████████▋                  |  ETA: 0:00:44QH7086 Qhull precision warning: repartition coplanar point p263 from f7 as an outside point above hidden facet f6 dist 3.9e-13 nearest vertices 0.011
# QH7086 Qhull precision warning: repartition coplanar point p285 from f7 as an outside point above hidden facet f7 dist 3.6e-13 nearest vertices 0.011
# QH7086 Qhull precision warning: repartition coplanar point p119 from f7 as an outside point above hidden facet f7 dist 3.6e-13 nearest vertices 0.011
# QH7086 Qhull precision warning: repartition coplanar point p507 from f7 as an outside point above hidden facet f7 dist 4.5e-13 nearest vertices 0.011
# QH7086 Qhull precision warning: repartition coplanar point p341 from f7 as an outside point above hidden facet f7 dist 4.1e-13 nearest vertices 0.011
# Progress:  89%|████████████████████████████████████▍    |  ETA: 0:00:19QH7086 Qhull precision warning: repartition coplanar point p32 from f7 as an outside point above hidden facet f6 dist 1.1e-12 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p67 from f7 as an outside point above hidden facet f6 dist 5.8e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p93 from f7 as an outside point above hidden facet f6 dist 8.9e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p127 from f7 as an outside point above hidden facet f6 dist 1.1e-12 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p146 from f7 as an outside point above hidden facet f6 dist 3.6e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p151 from f7 as an outside point above hidden facet f6 dist 5e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p154 from f7 as an outside point above hidden facet f6 dist 5.8e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p169 from f7 as an outside point above hidden facet f6 dist 8.9e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p184 from f7 as an outside point above hidden facet f6 dist 5.9e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p199 from f7 as an outside point above hidden facet f6 dist 5.3e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p219 from f7 as an outside point above hidden facet f6 dist 7.2e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p246 from f7 as an outside point above hidden facet f6 dist 6.4e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p277 from f7 as an outside point above hidden facet f6 dist 5.4e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p285 from f7 as an outside point above hidden facet f6 dist 9.2e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p317 from f7 as an outside point above hidden facet f6 dist 7.5e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p319 from f7 as an outside point above hidden facet f6 dist 1.1e-12 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p350 from f7 as an outside point above hidden facet f6 dist 6.8e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p359 from f7 as an outside point above hidden facet f6 dist 5e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p369 from f7 as an outside point above hidden facet f6 dist 5.5e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p380 from f7 as an outside point above hidden facet f6 dist 4.2e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p394 from f7 as an outside point above hidden facet f6 dist 8.6e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p431 from f7 as an outside point above hidden facet f6 dist 1.1e-12 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p492 from f7 as an outside point above hidden facet f6 dist 4.3e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p576 from f7 as an outside point above hidden facet f6 dist 5.6e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p606 from f7 as an outside point above hidden facet f6 dist 7.3e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p624 from f7 as an outside point above hidden facet f6 dist 5.8e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p646 from f7 as an outside point above hidden facet f6 dist 5.6e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p649 from f7 as an outside point above hidden facet f6 dist 7.8e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p683 from f7 as an outside point above hidden facet f6 dist 8.7e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p704 from f7 as an outside point above hidden facet f6 dist 7.6e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p765 from f7 as an outside point above hidden facet f6 dist 1.1e-12 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p794 from f7 as an outside point above hidden facet f6 dist 4.4e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p843 from f7 as an outside point above hidden facet f6 dist 1.1e-12 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p876 from f7 as an outside point above hidden facet f6 dist 9.8e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p881 from f7 as an outside point above hidden facet f6 dist 4.5e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p887 from f7 as an outside point above hidden facet f6 dist 6.2e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p888 from f7 as an outside point above hidden facet f6 dist 5.4e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p893 from f7 as an outside point above hidden facet f6 dist 6.2e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p936 from f7 as an outside point above hidden facet f6 dist 7.7e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p944 from f7 as an outside point above hidden facet f6 dist 1.1e-12 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p960 from f7 as an outside point above hidden facet f6 dist 9.2e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1011 from f7 as an outside point above hidden facet f6 dist 9.1e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1028 from f7 as an outside point above hidden facet f6 dist 4.7e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1034 from f7 as an outside point above hidden facet f6 dist 8.6e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1088 from f7 as an outside point above hidden facet f6 dist 9.2e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1091 from f7 as an outside point above hidden facet f6 dist 1.1e-12 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1137 from f7 as an outside point above hidden facet f6 dist 1.1e-12 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1140 from f7 as an outside point above hidden facet f6 dist 7.8e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1271 from f7 as an outside point above hidden facet f6 dist 1.2e-12 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1281 from f7 as an outside point above hidden facet f6 dist 5.9e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p50 from f7 as an outside point above hidden facet f6 dist 1.1e-12 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1343 from f7 as an outside point above hidden facet f6 dist 1.1e-12 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1374 from f7 as an outside point above hidden facet f6 dist 1e-12 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1376 from f7 as an outside point above hidden facet f6 dist 1.2e-12 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1487 from f7 as an outside point above hidden facet f6 dist 9.8e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1495 from f7 as an outside point above hidden facet f6 dist 1.1e-12 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1498 from f7 as an outside point above hidden facet f6 dist 1e-12 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1534 from f7 as an outside point above hidden facet f6 dist 7.6e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1579 from f7 as an outside point above hidden facet f6 dist 1.1e-12 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1595 from f7 as an outside point above hidden facet f6 dist 5.4e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1624 from f7 as an outside point above hidden facet f6 dist 8.8e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1631 from f7 as an outside point above hidden facet f6 dist 8.5e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1635 from f7 as an outside point above hidden facet f6 dist 4.2e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1663 from f7 as an outside point above hidden facet f6 dist 5.4e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1727 from f7 as an outside point above hidden facet f6 dist 6.5e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1809 from f7 as an outside point above hidden facet f6 dist 1.1e-12 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1817 from f7 as an outside point above hidden facet f6 dist 9.6e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1896 from f7 as an outside point above hidden facet f6 dist 1.1e-12 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1914 from f7 as an outside point above hidden facet f6 dist 1.1e-12 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1955 from f7 as an outside point above hidden facet f6 dist 6.4e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1967 from f7 as an outside point above hidden facet f6 dist 7.9e-13 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1982 from f7 as an outside point above hidden facet f6 dist 1.1e-12 nearest vertices 0.0068
# QH7086 Qhull precision warning: repartition coplanar point p1357 from f7 as an outside point above hidden facet f6 dist 1.2e-12 nearest vertices 0.0068
# Progress: 100%|█████████████████████████████████████████| Time: 0:03:01

# %%
plt1 = plot(title="Privacy-Adjusted Adjacency Matrix")
for k in eachindex(N)
    plot!(plt1, ϵ,
        with_eps[k] |> eachcol .|> median,
        ribbon = with_eps[k] |> eachcol .|> mad,
        marker=:o,
        label="n=$(N[k])",
        lw=3, fa=0.25,
    )
end
plt1 = plot(plt1, ylim=(0, 1.5), size=(500, 400))

# %%
plt2 = plot(title="Self-Normalized Embedding")
for k in eachindex(N)
    plot!(plt2, ϵ,
        without_eps[k] |> eachcol .|> median,
        ribbon = without_eps[k] |> eachcol .|> mad,
        marker=:o,
        label="n=$(N[k])",
        lw=3, fa=0.25,
    )
end
plt2 = plot(plt2, ylim=(0,1.5), size=(500,400))

# %%
lim = (-0.010, 2)
plot(plot(plt1, ylim=lim), plot(plt2, ylim=lim), size=(1000, 400))

# %%
savefig(plt1, plotsdir("comparisons/sim-with-eps.pdf"))

# %%
savefig(plt2, plotsdir("comparisons/sim-without-eps.pdf"))

# %%
plt1 = plot(title="Privacy-Adjusted Adjacency Matrix")
for k in eachindex(N)
    plot!(plt1, ϵ,
        with_eps[k] |> eachcol .|> median,
        ribbon = with_eps[k] |> eachcol .|> mad,
        marker=:o,
        label="n=$(N[k])",
        lw=2.5, fa=0.25, xticks=ϵ,
    )
end
plt1 = plot(plt1, ylim=(-1e-2, 1.1), lim=(0.9, 5.1), size=(500, 400))
savefig(plt1, plotsdir("comparisons/sim-with-eps.pdf"))

# %%
plt2 = plot(title="Self-Normalized Embedding")
for k in eachindex(N)
    plot!(plt2, ϵ,
        without_eps[k] |> eachcol .|> median,
        ribbon = without_eps[k] |> eachcol .|> mad,
        marker=:o,
        label="n=$(N[k])",
        lw=2.5, fa=0.25, xticks=ϵ,
    )
end
plt2 = plot(plt2, ylim=(-1e-2, 1.1), lim=(0.9, 5.1), size=(500, 400))
savefig(plt2, plotsdir("comparisons/sim-without-eps.pdf"))
